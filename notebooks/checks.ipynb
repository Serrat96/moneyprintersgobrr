# %%
import sqlite3
import pandas as pd

# Helpers
abspath = os.path.abspath
dirname = os.path.dirname
sep = os.sep

import warnings
warnings.filterwarnings("ignore")

# %%
dfs = {}
data_path = "../data/usa"

for file_ in os.listdir(data_path):
    dfs[file_[:-8].lower()] = pd.read_parquet(data_path + sep + file_)

# %%
dfs["na000334q"].iloc[-1]
# Out:
# NA000334Q    5.710187e+12
# Name: 2021-04-01 00:00:00, dtype: float64

# %%
n = 804
fact = 1
  
for i in range(1,n+1):
    fact = fact * i
      
print (f"The factorial of {n} is : ",end="")
print (fact)
# Out:
# The factorial of 804 is : ...
